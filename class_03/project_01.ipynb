# %% [markdown]
# <a href="https://colab.research.google.com/github/sheikh-mohammad/AI-101-YT-Projects/blob/main/Class_03/project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
is_hungry = True
is_burger_lover = True
is_pizza_lover = False

if (is_hungry and is_pizza_lover):
  print("Let's order the Pizza")
elif (is_hungry and is_burger_lover):
  print("Let's order the Burger")
