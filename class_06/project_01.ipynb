# %% [markdown]
# <a href="https://colab.research.google.com/github/sheikh-mohammad/ai-101-yt-projects/blob/main/class_06/project_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
users : list[dict] = [
    {
        "name" : "Sheikh Mohammad Ahmed",
        "father" : "Sohail Ahmed",
        "class" : "VIII"
    },
    {
        "name" : "Sheikh Ebad",
        "father" : "Sohail Ahmed",
        "class" : "I"
    },
    {
        "name" : "Aish Sohail",
        "father" : "Sohail Ahmed",
        "class" : "VI"
    }
]

print(f"Name for Student 1: {users[0]["name"]}")
print(f"Name for Student 2: {users[1]["name"]}")
print(f"Name for Student 3: {users[2]["name"]}")

print("------------------------------------------")

print(f"Father for Student 1: {users[0]["father"]}")
print(f"Father for Student 2: {users[1]["father"]}")
print(f"Father for Student 3: {users[2]["father"]}")

print("------------------------------------------")

print(f"Class for Student 1: {users[0]["class"]}")
print(f"Class for Student 2: {users[1]["class"]}")
print(f"Class for Student 3: {users[2]["class"]}")
# Out:
# Name for Student 1: Sheikh Mohammad Ahmed
# Name for Student 2: Sheikh Ebad
# Name for Student 3: Aish Sohail
# -------------------------
# Father for Student 1: Sohail Ahmed
# Father for Student 2: Sohail Ahmed
# Father for Student 3: Sohail Ahmed
# -------------------------
# Class for Student 1: VIII
# Class for Student 2: I
# Class for Student 3: VI
